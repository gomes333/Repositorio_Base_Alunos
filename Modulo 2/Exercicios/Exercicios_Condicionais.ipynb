# %% [markdown]
# ### 📝Lista de Exercícios: Condicionais IF/ELSE

# %% [markdown]
# Exercício 1 - Maioridade 🔞
#
# Crie um programa que pergunta a idade do usuário e diz se ele é maior ou menor de idade.

# %%
idade = int(input("Quantos anos você tem? "))

if idade >= 18:
    print("Você é maior de idade")
else:
    print("Você é menor de idade")

# Complete o código aqui
# Out:
# Você é maior de idade

# %% [markdown]
# Exercício 2 - Aprovação na Prova 🧠
#
# Faça um programa que pergunte a nota de um aluno (0 a 10) e diz se ele foi aprovado(nota >= 5) ou reprovado (nota <5).

# %%
nota = float(input("Informe a sua nota de (0 a 10)"))
if nota >=5:
    print("Aluno Aprovado")
else:
    if nota <=5:
        print("Aluno Reprovado")

# Complete o código aqui
# Out:
# Aluno Reprovado

# %% [markdown]
# Exercicio 3 - CNH 🚘🚙
#
#  1º - Peça ao usuário que digite a idade dele.
#
#  2º - Peça pra ele dizer se foi aprovado ou reprovado no curso de cnh.
#
#  3º - Use if e else para verificar se ele tem 18 anos ou mais e se foi aprovado.
#
#  4º - Se as condições do passo 3 estiverem certas, print("pode dirigir").
#
#  5º - Se não print("vai andar a pé")

# %%
### Seu código aqui
idade = int(input("Digite sua idade"))
cnh = input("Você foi aprovado ou reprovado?")
if idade >=18 and cnh== 'aprovado':
    print("Sua CNH foi aprovada, PODE DIRIGIR ")
else:
    print("Sua CNH foi reprovada,NÃO PODE DIRIGIR VAI ANDAR A PÉ")
# Out:
# Sua CNH foi reprovada,NÃO PODE DIRIGIR VAI ANDAR A PÉ

# %% [markdown]
# Exercício 4 - Calculadora de Desconto. 💵 🤑
#
# Uma loja dá 10% de desconto para compras acima de R$ 100,00. Faça um programa que:
#
# 1º - Pergunta o valor da compra.
#
# 2º - Calcula o valor final com desconto (se aplicável).
#
# 3º - Mostra o valor a pagar.

# %%
### Seu código aqui
valor_compra = float(input("Digite o valor da sua compra: R$"))

if valor_compra >100:
    desconto = valor_compra * 0.10
    valor_final = valor_compra - desconto
    print(f"Você ganhou 10% de desconto:R$ {desconto:.2f}")
else:
    valor_final = valor_compra
    print("Sem desconto para compras até  R$ 100,00")

print(f"Valor a pagar:R${valor_final:.2f}")
# Out:
# Você ganhou 10% de desconto:R$ 20.00
# Valor a pagar:R$180.00

# %% [markdown]
# Exercício 5 - Classificação de Notas 🧑‍🎓
#
# Pergunte a nota de um aluno e dependendo da nota que ele informar, o classifique de acordo com as regras abaixo:
#
# Classifique a nota do aluno:
#
# - 9 até 10: "Excelente"
#
# - 7 até 8.9: "Bom"
#
# - 5 até 6.9: "Regular"
#
# - 0 até 4.9: "Reprovado"
#
# mostre para o aluno a classificação dele através de um print, exemplo print("Excelente").

# %%
nota = float(input("Qual a sua nota ? :"))

if nota >=9 and nota <=10:
    print("Exelente")
elif nota >=7 and nota <=8.9:
    print("Bom")
elif nota >=5 and nota <=6.9:
    print("Regular")
elif nota >=0 and nota <=4.9:
    print("Reprovado")
else:
    print("Nota invalida.Digite um valor entre 0 e 10.")
# Out:
# Reprovado

# %% [markdown]
# Exercício 6 - Acesso ao Sistema 🔑
#
# Crie um login simples:
#
# - usuario_correto = "admin"
#
# - senha_correta = "1234"
#
# **Peça para o usuário digitar primeiro o login e depois a senha, caso login e senha estejam corretos programa deve mostrar "Acesso permitido" se não "Acesso negado"**

# %%
usuario_correto = "admin"
senha_correta = 1234

usuario = input("Faça seu login")
senha = input("Coloque a sua senha")
if usuario == usuario_correto and senha == senha_correta:
    print("Acesso permitido")
else:
    print("Acesso negado")
# Out:
# Acesso negado

# %% [markdown]
# Exercício 7 - Maior Número 📉
#
# Peça 3 números e mostre qual é o maior deles.

# %%
numero1 = float(input("Digire seu primeiro numero"))
numero2 = float(input("Digire seu segundo numero"))
numero3 = float(input("Digire seu terceiro numero"))

maior = max(numero1,numero2,numero3)
print(f"O maior número é:{maior}")
# Out:
# O maior número é:19.0

# %% [markdown]
# Exercício 8 - Dia da Semana
# Peça um número de 1 a 7 e mostre o dia da semana correspondente: 📅
#
# - 1: Domingo
#
# - 2: Segunda
#
# - ... até 7: Sábado

# %%
numero = int(input("Digite um número de 1 até 7"))

if numero == 1:
    print("Domingo")
elif numero == 2:
    print("Segunda")
elif numero == 3:
    print("Terça")
elif numero == 4:
    print("Quarta")
elif numero == 5:
    print("Quinta")
elif numero == 6:
    print("Sexta")
elif numero == 7:
    print("Sábado")
else:
    print("Número inválido! Digite um valor entre 1 e 7.")
# Out:
# Sexta

# %% [markdown]
# Exercício 9 - Calculadora Simples 📏📐
#
# - Faça uma calculadora que:
#
# - Pede dois números
#
# - Pede a operação (+, -, *, /)
#
# - Dependendo da operação mostre o resultado.

# %%
numero1 = float(input("Digite o 1º número: "))
numero2 = float(input("Digite o 2º número: "))
operacao = input("Digite a operação (+, -, *, /): ")

if operacao == "+":
    resultado = numero1 + numero2
elif operacao == "-":
    resultado = numero1 - numero2
elif operacao == "*":
    resultado = numero1 * numero2
elif operacao == "/":
    if numero2 != 0:
        resultado = numero1 / numero2
    else:
        print("Erro: Não dá pra dividir por zero!")
        resultado = None
else:
    print("Operação inválida! Use +, -, * ou /")
    resultado = None

if resultado is not None:
    print(f"Resultado: {resultado}")
# Out:
# Operação inválida! Use +, -, * ou /

# %% [markdown]
# Exercício 10 - Sistema de Multas 🚙🚘🧾
#
#
# - Velocidade máxima: 80 km/h 🚫
#
# - Até 80: "Sem multa"
#
# - 81-100: "Multa leve"
#
# - Acima de 100: "Multa grave"

# %%
velocidade = float(input("Digite a velocidade do carro em KM/h:"))

if velocidade <=80:
    print("Sem multa")
elif velocidade >=81 and velocidade <=100:
    print("Multa leve")
else:
    print("Multa grave")
# Out:
# Multa leve
